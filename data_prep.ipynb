# %% [markdown]
# # Data Prep Notebook
#
# This notebook was written to download Zillow data and merge is with U.S. census county geodata as well as area deprivation data.  The notebook was written to test data engineering code which will later be transferred to python scripts.

# %%
import pandas as pd
from google.cloud import bigquery
import pandas_gbq

from data_download_utilities import csv_download, bq_download

# %%
avi_df = bq_download('SELECT * FROM `bigquery-public-data.broadstreet_adi.area_deprivation_index_by_county` WHERE YEAR = 2020 AND state_fips_code = "48"')
avi_df
# Out:
#            geo_id state_fips_code county_fips_code      county_name  \
# 0    05000US48001              48            48001  Anderson County
# 1    05000US48003              48            48003   Andrews County
# 2    05000US48005              48            48005  Angelina County
# 3    05000US48007              48            48007   Aransas County
# 4    05000US48009              48            48009    Archer County
# ..            ...             ...              ...              ...
# 249  05000US48499              48            48499      Wood County
# 250  05000US48501              48            48501    Yoakum County
# 251  05000US48503              48            48503     Young County
# 252  05000US48505              48            48505    Zapata County
# 253  05000US48507              48            48507    Zavala County
#
#     state_name state  year  area_deprivation_index_percent
# 0        Texas    TX  2020                            70.0
# 1        Texas    TX  2020                            54.0
# 2        Texas    TX  2020                            80.0
# 3        Texas    TX  2020                            63.0
# 4        Texas    TX  2020                            17.0
# ..         ...   ...   ...                             ...
# 249      Texas    TX  2020                            52.0
# 250      Texas    TX  2020                            68.0
# 251      Texas    TX  2020                            60.0
# 252      Texas    TX  2020                           100.0
# 253      Texas    TX  2020                           100.0
#
# [254 rows x 8 columns]

# %%
tx_geo_df = bq_download('SELECT * FROM `bigquery-public-data.geo_us_boundaries.counties` where state_fips_code = "48"')
tx_geo_df
# Out:
#     geo_id state_fips_code county_fips_code county_gnis_code county_name  \
# 0    48383              48            48383         01383977      Reagan
# 1    48461              48            48461         01384016       Upton
# 2    48089              48            48089         01383830    Colorado
# 3    48337              48            48337         01383954    Montague
# 4    48299              48            48299         01383935       Llano
# ..     ...             ...              ...              ...         ...
# 249  48145              48            48145         01383858       Falls
# 250  48485              48            48485         01384028     Wichita
# 251  48077              48            48077         01383824        Clay
# 252  48009              48            48009         01383790      Archer
# 253  48505              48            48505         01384038      Zapata
#
#            lsad_name lsad_code fips_class_code mtfcc_feature_class_code  \
# 0      Reagan County        06              H1                    G4020
# 1       Upton County        06              H1                    G4020
# 2    Colorado County        06              H1                    G4020
# 3    Montague County        06              H1                    G4020
# 4       Llano County        06              H1                    G4020
# ..               ...       ...             ...                      ...
# 249     Falls County        06              H1                    G4020
# 250   Wichita County        06              H1                    G4020
# 251      Clay County        06              H1                    G4020
# 252    Archer County        06              H1                    G4020
# 253    Zapata County        06              H1                    G4020
#
#     csa_fips_code cbsa_fips_code met_div_fips_code functional_status  \
# 0            None           None              None                 A
# 1            None           None              None                 A
# 2            None           None              None                 A
# 3            None           None              None                 A
# 4            None           None              None                 A
# ..            ...            ...               ...               ...
# 249          None          47380              None                 A
# 250          None          48660              None                 A
# 251          None          48660              None                 A
# 252          None          48660              None                 A
# 253          None          49820              None                 A
#
#      area_land_meters  area_water_meters  int_point_lat  int_point_lon  \
# 0          3044049120            1792716      31.375191    -101.514395
# 1          3215010598             464309      31.353816    -102.041546
# 2          2487129887           34703995      29.596296     -96.508935
# 3          2411034607           19087361      33.678356     -97.725014
# 4          2419185654           82370906      30.707584     -98.684690
# ..                ...                ...            ...            ...
# 249        1982545002           21693803      31.251930     -96.934128
# 250        1625459969           13644166      33.988213     -98.708010
# 251        2819870186           72508536      33.785904     -98.212917
# 252        2339508173           57767712      33.616305     -98.687267
# 253        2585876219          154370982      26.996981     -99.182603
#
#                      int_point_geom  \
# 0    POINT(-101.5143954 31.3751911)
# 1    POINT(-102.0415461 31.3538163)
# 2      POINT(-96.5089347 29.596296)
# 3     POINT(-97.7250138 33.6783558)
# 4     POINT(-98.6846901 30.7075845)
# ..                              ...
# 249   POINT(-96.9341275 31.2519298)
# 250   POINT(-98.7080098 33.9882125)
# 251   POINT(-98.2129174 33.7859042)
# 252   POINT(-98.6872669 33.6163054)
# 253   POINT(-99.1826027 26.9969806)
#
#                                            county_geom
# 0    POLYGON((-101.776176 31.081392, -101.776191 31...
# 1    POLYGON((-102.009444 31.082669, -102.000409 31...
# 2    POLYGON((-96.706155 29.486696, -96.705809 29.4...
# 3    POLYGON((-97.978804 33.727526, -97.978805 33.7...
# 4    POLYGON((-98.964016 30.705236, -98.964017 30.7...
# ..                                                 ...
# 249  POLYGON((-97.017623 31.410927, -97.018061 31.4...
# 250  POLYGON((-98.423546 34.018645, -98.423618 34.0...
# 251  POLYGON((-98.42308 33.944531, -98.423081 33.94...
# 252  POLYGON((-98.751999 33.395871, -98.750339 33.3...
# 253  POLYGON((-99.385401 26.981377, -99.384981 26.9...
#
# [254 rows x 19 columns]

# %%
zillow_df = csv_download('https://files.zillowstatic.com/research/public_csvs/zhvi/County_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv?t=1719616688')

# Subset on Texas
zillow_tx_df = zillow_df[zillow_df['State'] == 'TX']
zillow_tx_df['StateCodeFIPS'] = zillow_tx_df['StateCodeFIPS'].astype(str)
zillow_tx_df['MunicipalCodeFIPS'] = zillow_tx_df['MunicipalCodeFIPS'].astype(str)
zillow_tx_df['StateCodeFIPS'] = zillow_tx_df['StateCodeFIPS'].apply('{:0>2}'.format)
zillow_tx_df['MunicipalCodeFIPS'] = zillow_tx_df['MunicipalCodeFIPS'].apply('{:0>3}'.format)
zillow_tx_df['county_fips_code'] =  zillow_tx_df['StateCodeFIPS'] + zillow_tx_df['MunicipalCodeFIPS']

months_to_avg_list = []
for n in zillow_tx_df.columns:
    if n[0:4] == '2020':
        print(n)
        months_to_avg_list.append(n)
zillow_tx_df['average'] = zillow_tx_df[months_to_avg_list].mean(axis=1)
# Need to drop State column to avoid a conflict in variable names when merging:
zillow_tx_df.drop('State', axis = 1, inplace = True)

zillow_tx_df
# Out:
# 2020-01-31
# 2020-02-29
# 2020-03-31
# 2020-04-30
# 2020-05-31
# 2020-06-30
# 2020-07-31
# 2020-08-31
# 2020-09-30
# 2020-10-31
# 2020-11-30
# 2020-12-31
# /var/tmp/ipykernel_5741/4079113788.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zillow_tx_df['StateCodeFIPS'] = zillow_tx_df['StateCodeFIPS'].astype(str)
# /var/tmp/ipykernel_5741/4079113788.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zillow_tx_df['MunicipalCodeFIPS'] = zillow_tx_df['MunicipalCodeFIPS'].astype(str)
# /var/tmp/ipykernel_5741/4079113788.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zillow_tx_df['StateCodeFIPS'] = zillow_tx_df['StateCodeFIPS'].apply('{:0>2}'.format)
# /var/tmp/ipykernel_5741/4079113788.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zillow_tx_df['MunicipalCodeFIPS'] = zillow_tx_df['MunicipalCodeFIPS'].apply('{:0>3}'.format)
# /var/tmp/ipykernel_5741/4079113788.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zillow_tx_df['county_fips_code'] =  zillow_tx_df['StateCodeFIPS'] + zillow_tx_df['MunicipalCodeFIPS']
# /var/tmp/ipykernel_5741/4079113788.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zillow_tx_df['average'] = zillow_tx_df[months_to_avg_list].mean(axis=1)
# /var/tmp/ipykernel_5741/4079113788.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zillow_tx_df.drop('State', axis = 1, inplace = True)
#       RegionID  SizeRank        RegionName RegionType StateName  \
# 2         1090         2     Harris County     county        TX
# 8          978         8     Dallas County     county        TX
# 14        2049        14    Tarrant County     county        TX
# 15         386        15      Bexar County     county        TX
# 33        1440        33     Travis County     county        TX
# ...        ...       ...               ...        ...       ...
# 3044      1247      3171     Motley County     county        TX
# 3045      1557      3172    Briscoe County     county        TX
# 3048      2706      3175  Glasscock County     county        TX
# 3050       518      3178      Foard County     county        TX
# 3054      2052      3184    Terrell County     county        TX
#
#                                      Metro StateCodeFIPS MunicipalCodeFIPS  \
# 2     Houston-The Woodlands-Sugar Land, TX            48               201
# 8          Dallas-Fort Worth-Arlington, TX            48               113
# 14         Dallas-Fort Worth-Arlington, TX            48               439
# 15           San Antonio-New Braunfels, TX            48               029
# 33        Austin-Round Rock-Georgetown, TX            48               453
# ...                                    ...           ...               ...
# 3044                                   NaN            48               345
# 3045                                   NaN            48               045
# 3048                                   NaN            48               173
# 3050                                   NaN            48               155
# 3054                                   NaN            48               443
#
#          2000-01-31     2000-02-29  ...     2023-10-31     2023-11-30  \
# 2     111014.888728  110986.387143  ...  284948.059503  284693.543837
# 8      96618.812191   96672.070463  ...  319988.065224  320046.888242
# 14    114637.326313  114709.951201  ...  332494.890444  332383.098229
# 15    103545.511714  103643.697618  ...  272190.337605  270916.701106
# 33    189092.292447  189710.624810  ...  535337.368601  531653.587084
# ...             ...            ...  ...            ...            ...
# 3044            NaN            NaN  ...   97666.006365   95097.426710
# 3045            NaN            NaN  ...   94201.503184   91538.637597
# 3048            NaN            NaN  ...  245918.050851  245825.731384
# 3050            NaN            NaN  ...  122837.341055  120325.111516
# 3054            NaN            NaN  ...  103091.255061  102020.927374
#
#          2023-12-31     2024-01-31     2024-02-29     2024-03-31  \
# 2     284398.217589  284510.879505  284979.598951  285995.201590
# 8     319942.293815  320142.012121  320972.695634  322460.881161
# 14    332214.432397  332252.111874  332354.308134  332785.323754
# 15    269414.366137  268324.083911  267761.822952  267935.129626
# 33    527761.861210  524869.794009  522741.348936  521926.791189
# ...             ...            ...            ...            ...
# 3044   92690.144412   91123.621370   91385.345818   93333.151040
# dtype: object

# %%
avi_df.dtypes
# Out:
# geo_id                             object
# state_fips_code                    object
# county_fips_code                   object
# county_name                        object
# state_name                         object
# state                              object
# year                                Int64
# area_deprivation_index_percent    float64
# dtype: object

# %%
merged_df = pd.merge(tx_geo_df, avi_df, on='county_fips_code', how = 'outer')

merged_df
# Out:
#     geo_id_x state_fips_code_x county_fips_code county_gnis_code  \
# 0      48383                48            48383         01383977
# 1      48461                48            48461         01384016
# 2      48089                48            48089         01383830
# 3      48337                48            48337         01383954
# 4      48299                48            48299         01383935
# ..       ...               ...              ...              ...
# 249    48145                48            48145         01383858
# 250    48485                48            48485         01384028
# 251    48077                48            48077         01383824
# 252    48009                48            48009         01383790
# 253    48505                48            48505         01384038
#
#     county_name_x        lsad_name lsad_code fips_class_code  \
# 0          Reagan    Reagan County        06              H1
# 1           Upton     Upton County        06              H1
# 2        Colorado  Colorado County        06              H1
# 3        Montague  Montague County        06              H1
# 4           Llano     Llano County        06              H1
# ..            ...              ...       ...             ...
# 249         Falls     Falls County        06              H1
# 250       Wichita   Wichita County        06              H1
# 251          Clay      Clay County        06              H1
# 252        Archer    Archer County        06              H1
# 253        Zapata    Zapata County        06              H1
#
#     mtfcc_feature_class_code csa_fips_code  ... int_point_lon  \
# 0                      G4020          None  ...   -101.514395
# 1                      G4020          None  ...   -102.041546
# 2                      G4020          None  ...    -96.508935
# 3                      G4020          None  ...    -97.725014
# 4                      G4020          None  ...    -98.684690
# ..                       ...           ...  ...           ...
# 249                    G4020          None  ...    -96.934128
# 250                    G4020          None  ...    -98.708010
# 251                    G4020          None  ...    -98.212917
# 252                    G4020          None  ...    -98.687267
# 253                    G4020          None  ...    -99.182603
#
#                      int_point_geom  \
# 0    POINT(-101.5143954 31.3751911)
# 1    POINT(-102.0415461 31.3538163)
# 2      POINT(-96.5089347 29.596296)
# 3     POINT(-97.7250138 33.6783558)
# 4     POINT(-98.6846901 30.7075845)
# ..                              ...
# 249   POINT(-96.9341275 31.2519298)
# 250   POINT(-98.7080098 33.9882125)
# 251   POINT(-98.2129174 33.7859042)
# 252   POINT(-98.6872669 33.6163054)
# 253   POINT(-99.1826027 26.9969806)
#
#                                            county_geom      geo_id_y  \
# 0    POLYGON((-101.776176 31.081392, -101.776191 31...  05000US48383
# 1    POLYGON((-102.009444 31.082669, -102.000409 31...  05000US48461
# 2    POLYGON((-96.706155 29.486696, -96.705809 29.4...  05000US48089
# 3    POLYGON((-97.978804 33.727526, -97.978805 33.7...  05000US48337
# 4    POLYGON((-98.964016 30.705236, -98.964017 30.7...  05000US48299
# ..                                                 ...           ...
# 249  POLYGON((-97.017623 31.410927, -97.018061 31.4...  05000US48145
# 250  POLYGON((-98.423546 34.018645, -98.423618 34.0...  05000US48485
# 251  POLYGON((-98.42308 33.944531, -98.423081 33.94...  05000US48077
# 252  POLYGON((-98.751999 33.395871, -98.750339 33.3...  05000US48009
# 253  POLYGON((-99.385401 26.981377, -99.384981 26.9...  05000US48505
#
#      state_fips_code_y    county_name_y  state_name state  year  \
# 0                   48    Reagan County       Texas    TX  2020
# 1                   48     Upton County       Texas    TX  2020
# 2                   48  Colorado County       Texas    TX  2020
# 3                   48  Montague County       Texas    TX  2020
# 4                   48     Llano County       Texas    TX  2020
# ..                 ...              ...         ...   ...   ...
# 249                 48     Falls County       Texas    TX  2020
# 250                 48   Wichita County       Texas    TX  2020
# 251                 48      Clay County       Texas    TX  2020
# 252                 48    Archer County       Texas    TX  2020
# 253                 48    Zapata County       Texas    TX  2020
#
#     area_deprivation_index_percent
# 0                             57.0
# 1                             79.0
# 2                             59.0
# 3                             60.0
# 4                             41.0
# ..                             ...
# 249                           95.0
# 250                           67.0
# 251                           33.0
# 252                           17.0
# 253                          100.0
#
# [254 rows x 26 columns]

# %%
merged_df = pd.merge(merged_df, zillow_tx_df, on='county_fips_code', how = 'outer')

merged_df
# Out:
#     geo_id_x state_fips_code_x county_fips_code county_gnis_code  \
# 0      48383                48            48383         01383977
# 1      48461                48            48461         01384016
# 2      48089                48            48089         01383830
# 3      48337                48            48337         01383954
# 4      48299                48            48299         01383935
# ..       ...               ...              ...              ...
# 249    48145                48            48145         01383858
# 250    48485                48            48485         01384028
# 251    48077                48            48077         01383824
# 252    48009                48            48009         01383790
# 253    48505                48            48505         01384038
#
#     county_name_x        lsad_name lsad_code fips_class_code  \
# 0          Reagan    Reagan County        06              H1
# 1           Upton     Upton County        06              H1
# 2        Colorado  Colorado County        06              H1
# 3        Montague  Montague County        06              H1
# 4           Llano     Llano County        06              H1
# ..            ...              ...       ...             ...
# 249         Falls     Falls County        06              H1
# 250       Wichita   Wichita County        06              H1
# 251          Clay      Clay County        06              H1
# 252        Archer    Archer County        06              H1
# 253        Zapata    Zapata County        06              H1
#
#     mtfcc_feature_class_code csa_fips_code  ...     2023-09-30     2023-10-31  \
# 0                      G4020          None  ...  151593.594208  153884.130270
# 1                      G4020          None  ...   97675.480157   97826.160360
# 2                      G4020          None  ...  237368.132749  237187.707142
# 3                      G4020          None  ...  222990.742347  221881.491042
# 4                      G4020          None  ...  506123.719839  501978.769786
# ..                       ...           ...  ...            ...            ...
# 249                    G4020          None  ...  128857.470890  127088.633373
# 250                    G4020          None  ...  159456.957189  159870.686556
# 251                    G4020          None  ...  180736.334171  179660.508860
# 252                    G4020          None  ...  212070.069320  211676.261763
# 253                    G4020          None  ...  125216.213943  123572.411994
#
#         2023-11-30     2023-12-31     2024-01-31     2024-02-29  \
# 0    154432.645370  153434.422649  151729.337150  151166.159237
# 1     97581.650623   96527.286018   94936.375187   93488.987551
# 2    236523.842733  235143.246022  234457.291839  234680.596399
# 3    221692.064806  220675.994076  219564.056322  218880.150997
# 4    497002.974799  491334.084753  487284.663999  484163.205366
# ..             ...            ...            ...            ...
# 249  125196.059188  123473.109204  123384.143036  123696.463221
# 250  160214.134584  160189.635075  160173.271505  160560.097609
# 251  178532.175357  177373.737730  177092.953193  177849.439200
# 252  210522.277219  209468.769280  209349.763630  210636.005873
# 253  121363.773067  119323.182863  117636.273748  116823.103578
#
#     mtfcc_feature_class_code csa_fips_code  ...  \
# 0                      G4020          None  ...
# 1                      G4020          None  ...
# 2                      G4020          None  ...
# 3                      G4020          None  ...
# 4                      G4020          None  ...
# ..                       ...           ...  ...
# 249                    G4020          None  ...
# 250                    G4020          None  ...
# 251                    G4020          None  ...
# 252                    G4020          None  ...
# 253                    G4020          None  ...
#
#     area_deprivation_index_percent RegionID SizeRank       RegionName  \
# 0                             57.0   1353.0   3015.0    Reagan County
# 1                             79.0    780.0   3018.0     Upton County
# 2                             59.0   2209.0   1846.0  Colorado County
# 3                             60.0   2442.0   1882.0  Montague County
# 4                             41.0    603.0   1812.0     Llano County
# ..                             ...      ...      ...              ...
# 249                           95.0    509.0   2029.0     Falls County
# 250                           67.0   2095.0    500.0   Wichita County
# 251                           33.0    132.0   2469.0      Clay County
# 252                           17.0    835.0   2603.0    Archer County
# 253                          100.0   1506.0   2230.0    Zapata County
#
#      RegionType  StateName              Metro StateCodeFIPS MunicipalCodeFIPS  \
# 0        county         TX                NaN            48               383
# 1        county         TX                NaN            48               461
# 2        county         TX                NaN            48               089
# 3        county         TX                NaN            48               337
# 4        county         TX                NaN            48               299
# ..          ...        ...                ...           ...               ...
# 249      county         TX           Waco, TX            48               145
# 250      county         TX  Wichita Falls, TX            48               485
# 251      county         TX  Wichita Falls, TX            48               077
# 252      county         TX  Wichita Falls, TX            48               009
# 253      county         TX         Zapata, TX            48               505
#
#            average
# 0              NaN
# 1    114668.017466
# 2    194684.853214
# 3    162273.463390
# 4    346568.566084
# ..             ...
# 249  116745.560985
# 250  111817.914505
# 251  142894.023659
# 252  166031.803063
# 253  131185.246385
#
# [254 rows x 35 columns]

# %%
# Construct a BigQuery client object.
client = bigquery.Client()

project_id = "even-gearbox-427900-t9"
dataset_name = "avi_housing"

# TODO(developer): Set dataset_id to the ID of the dataset to create.
dataset_id = f'{project_id}.{dataset_name}'.format(client.project)

# Construct a full Dataset object to send to the API.
dataset = bigquery.Dataset(dataset_id)

# TODO(developer): Specify the geographic location where the dataset should reside.
dataset.location = "US"

# Send the dataset to the API for creation, with an explicit timeout.
# Raises google.api_core.exceptions.Conflict if the Dataset already
# exists within the project.
dataset = client.create_dataset(dataset, timeout=30)  # Make an API request.
print("Created dataset {}.{}".format(client.project, dataset.dataset_id))
# Out:
# ---------------------------------------------------------------------------
# Conflict                                  Traceback (most recent call last)
# Cell In[95], line 19
#      14 dataset.location = "US"
#      16 # Send the dataset to the API for creation, with an explicit timeout.
#      17 # Raises google.api_core.exceptions.Conflict if the Dataset already
#      18 # exists within the project.
# ---> 19 dataset = client.create_dataset(dataset, timeout=30)  # Make an API request.
#      20 print("Created dataset {}.{}".format(client.project, dataset.dataset_id))
#
# File /opt/conda/lib/python3.9/site-packages/google/cloud/bigquery/client.py:677, in Client.create_dataset(self, dataset, exists_ok, retry, timeout)
#     674 try:
#     675     span_attributes = {"path": path}
# --> 677     api_response = self._call_api(
#     678         retry,
#     679         span_name="BigQuery.createDataset",
#     680         span_attributes=span_attributes,
#     681         method="POST",
#     682         path=path,
#     683         data=data,
#     684         timeout=timeout,
#     685     )
#     686     return Dataset.from_api_repr(api_response)
#     687 except core_exceptions.Conflict:
#
# File /opt/conda/lib/python3.9/site-packages/google/cloud/bigquery/client.py:827, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     823 if span_name is not None:
#     824     with create_span(
#     825         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     826     ):
# --> 827         return call()
#     829 return call()
#
# File /opt/conda/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File /opt/conda/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     149 # pylint: disable=broad-except
#     150 # This function explicitly must deal with broad exceptions.
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#     164     time.sleep(sleep)
#
# File /opt/conda/lib/python3.9/site-packages/google/api_core/retry/retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     206 if not predicate_fn(exc):
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#     214     on_error_fn(exc)
#
# File /opt/conda/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File /opt/conda/lib/python3.9/site-packages/google/cloud/_http/__init__.py:494, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#    (...)
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
# --> 494     raise exceptions.from_http_response(response)
#     496 if expect_json and response.content:
#     497     return response.json()
#
# Conflict: 409 POST https://bigquery.googleapis.com/bigquery/v2/projects/even-gearbox-427900-t9/datasets?prettyPrint=false: Already Exists: Dataset even-gearbox-427900-t9:avi_housing

# %%
# TODO: Set project_id to your Google Cloud Platform project ID.
# project_id = "my-project"
# TODO: Set table_id to the full destination table ID (including the
#       dataset ID).
table_id = 'merged_data'
table_id_combined = f'{dataset_name}.{table_id}'


pandas_gbq.to_gbq(merged_df, table_id_combined, project_id=project_id, table_schema=[{'name': 'county_geom', 'type': 'GEOGRAPHY'}])
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 8924.05it/s]

# %%
for n in merged_df.columns.to_lower().sort_values():
    print(n)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 for n in merged_df.columns.to_lower().sort_values():
#       2     print(n)
#
# AttributeError: 'Index' object has no attribute 'to_lower'

# %%
data = merged_df
data.columns = [x.lower() for x in data.columns]
for n in data.columns.sort_values():
    print(n)
# Out:
# area_deprivation_index_percent
# area_land_meters
# area_water_meters
# average
# cbsa_fips_code
# county_fips_code
# county_geom
# county_gnis_code
# county_name_x
# county_name_y
# csa_fips_code
# fips_class_code
# functional_status
# geo_id_x
# geo_id_y
# int_point_geom
# int_point_lat
# int_point_lon
# lsad_code
# lsad_name
# met_div_fips_code
# metro
# mtfcc_feature_class_code
# municipalcodefips
# regionid
# regionname
# regiontype
# sizerank
# state
# state_fips_code_x
# state_fips_code_y
# state_name
# statecodefips
# statename
# year

# %%
for n in avi_df.columns:
    print(n)
# Out:
# geo_id
# state_fips_code
# county_fips_code
# county_name
# state_name
# state
# year
# area_deprivation_index_percent
